# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#redWine
red_wine = pd.read_csv('data/winequality-red.csv',sep=";")
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#witewine 
white_wine = pd.read_csv('data/winequality-white.csv',sep=";")
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# # Question

# %% [markdown]
# 1 اي العناصر هتاثر فى جوده المنتج
# 2-هل النبيد الأحمر افضل من النبيد الابيض
# 3-هل نسبه الكحول/ السكر / الكثافه / درجه الحموضه تؤثر في الجوده

# %%
#num of row to red_wine
row , column = red_wine.shape
print('the number of row in red wine is:', row , ' and number of columns is :',column)
# Out:
# the number of row in red wine is: 1599  and number of columns is : 12

# %%
row , column = white_wine.shape
print('the number of row in white wine is:', row , ' and number of columns is :',column)
# Out:
# the number of row in white wine is: 4898  and number of columns is : 12

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
idx =[]
for i , v in enumerate(red_wine.duplicated()):
    if v == True:
        idx.append(i)
idx        
red_wine.iloc[idx].head()
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4             7.4             0.700         0.00            1.90      0.076
# 11            7.5             0.500         0.36            6.10      0.071
# 27            7.9             0.430         0.21            1.60      0.106
# 40            7.3             0.450         0.36            5.90      0.074
# 65            7.2             0.725         0.05            4.65      0.086
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 27                 10.0                  37.0   0.9966  3.17       0.91
# 40                 12.0                  87.0   0.9978  3.33       0.83
# 65                  4.0                  11.0   0.9962  3.41       0.39
#
#     alcohol  quality
# 4       9.4        5
# 11     10.5        5
# ...

# %%
red_wine.duplicated().sum()
# Out:
# 240

# %%
uni_quality = red_wine['quality']

# %%
np.unique(uni_quality)
# Out:
# array([3, 4, 5, 6, 7, 8], dtype=int64)

# %%
np.mean(red_wine['density'])
# Out:
# 0.9967466791744833

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
red_wine['color']='red'

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
white_wine['color']='white'

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %%
wine_df = white_wine.append(red_wine ,ignore_index=True)

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
# fixed acidity           6497 non-null float64
# volatile acidity        6497 non-null float64
# citric acid             6497 non-null float64
# residual sugar          6497 non-null float64
# chlorides               6497 non-null float64
# free sulfur dioxide     6497 non-null float64
# total sulfur dioxide    6497 non-null float64
# density                 6497 non-null float64
# pH                      6497 non-null float64
# sulphates               6497 non-null float64
# alcohol                 6497 non-null float64
# quality                 6497 non-null int64
# color                   6497 non-null object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 659.9+ KB

# %%
wine_df.rename(columns={'pH':'potential of Hydrogen'} ,inplace=True)

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density  potential of Hydrogen  \
# 0                 45.0                 170.0   1.0010                   3.00
# 1                 14.0                 132.0   0.9940                   3.30
# 2                 30.0                  97.0   0.9951                   3.26
# 3                 47.0                 186.0   0.9956                   3.19
# 4                 47.0                 186.0   0.9956                   3.19
#
#    sulphates  alcohol  quality  color
# ...

# %%
wine_df.hist(figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000044914B1EF0>,
# ...
#       dtype=object)

# %%
wine_df['quality'].value_counts().plot(kind='pie')

# %%
wine_df.plot.scatter(x='alcohol',y='quality')

# %%
wine_df.plot.scatter(x='potential of Hydrogen',y='quality')

# %%
wine_df.plot.scatter(x='volatile acidity',y='quality')

# %%
wine_df.plot.scatter(x='residual sugar',y='quality')

# %%
wine_df.groupby('color').mean()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# color
# red         8.319637          0.527821     0.270976        2.538806
# white       6.854788          0.278241     0.334192        6.391415
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# color
# red     0.087467            15.874922             46.467792  0.996747
# white   0.045772            35.308085            138.360657  0.994027
#
#        potential of Hydrogen  sulphates    alcohol   quality
# color
# red                 3.311113   0.658149  10.422983  5.636023
# white               3.188267   0.489847  10.514267  5.877909

# %%
wine_df.groupby('color')['quality'].mean()
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
bin_edges = [2.72, 3.11,3.21, 3.32, 4.01]
pd.cut(wine_df['potential of Hydrogen'] ,bin_edges ,labels=['High','Moderately High','Medium','Low'] )
